# %% [markdown]
# # Census income
# ## Exploracyjna analiza danych

# %% [markdown]
# ## 1. Importowanie zbioru danych

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, FunctionTransformer

# %%
data = pd.read_csv ('census_income_dataset.csv')
data
# Out:
#        age         workclass    fnlwgt  education  education_num  \
# 0       39         State-gov   77516.0  Bachelors             13
# 1       50  Self-emp-not-inc   83311.0  Bachelors             13
# 2       38           Private  215646.0    HS-grad              9
# 3       53           Private  234721.0       11th              7
# 4       28           Private  338409.0  Bachelors             13
# ...    ...               ...       ...        ...            ...
# 48837   39           Private  215419.0  Bachelors             13
# 48838   64                 ?  321403.0    HS-grad              9
# 48839   38           Private  374983.0  Bachelors             13
# 48840   44           Private   83891.0  Bachelors             13
# 48841   35      Self-emp-inc  182148.0  Bachelors             13
#
#            marital_status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                  ?  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 0                   White    Male        2174.0           0.0            40.0
# 1                   White    Male           0.0           0.0            13.0
# 2                   White    Male           0.0           0.0            40.0
# 3                   Black    Male           0.0           0.0            40.0
# 4                   Black  Female           0.0           0.0            40.0
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female           0.0           0.0            36.0
# 48838               Black    Male           0.0           0.0            40.0
# 48839               White    Male           0.0           0.0            50.0
# 48840  Asian-Pac-Islander    Male        5455.0           0.0            40.0
# 48841               White    Male           0.0           0.0            60.0
#
#       native_country income_level
# 0      United-States        <=50K
# 1      United-States        <=50K
# 2      United-States        <=50K
# 3      United-States        <=50K
# 4               Cuba        <=50K
# ...              ...          ...
# 48837  United-States        <=50K
# 48838  United-States        <=50K
# 48839  United-States        <=50K
# 48840  United-States        <=50K
# 48841  United-States         >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# ## 2. Informacje o danych

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income_level'],
#       dtype='object')

# %% [markdown]
# Opis kolumn:

# %%
attr = pd.read_csv("attributes_census_income.csv")
with pd.option_context('display.max_colwidth', 400):
    display(attr)
# Out:
#               name     type  \
# 0              age  integer
# 1        workclass   string
# 2           fnlwgt    float
# 3        education   string
# 4    education_num  integer
# 5   marital_status   string
# 6       occupation   string
# 7     relationship   string
# 8             race   string
# 9              sex   string
# 10    capital_gain    float
# 11    capital_loss    float
# 12  hours_per_week    float
# 13  native_country   string
# 14    income_level   string
#
#                                                                                                                                                                                                                                                                                                                                                                                                         description
# 0                                                                                                                                                                                                                                                                                                                                                                                                 age of individual
# 1                                                                                                                                                                                                                                                                                                     Values: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked
# 2                                                                                                                                                                                                                                                                                     Final sampling weight. Inverse of sampling fraction adjusted for non-response and over or under sampling of particular groups
# 3                                                                                                                                                                                                                                                     Values: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool
# 4                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 5                                                                                                                                                                                                                                                                                                 Values: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse
# 6                                                                                                                                                                                  Values: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces
# 7                                                                                                                                                                                                                                                                                                                                        Values: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried
# 8                                                                                                                                                                                                                                                                                                                                               Values: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black
# 9                                                                                                                                                                                                                                                                                                                                                                                              Values: Female, Male
# 10                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 11                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 12                                                                                                                                                                                                                                                                                                                                                                                           working hours per week
# 13  Values: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru...
# 14                                                                                                                                                                                                                                                                                                                    Predictor class if individual earns greater or less than $50000 per year. Values: <=50K, >50K

# %%
data.drop("fnlwgt", axis=1, inplace=True)

# %% [markdown]
# Zmienna `fnlwgt` to zmienna statystyczna, nie będzie potrzeba do budowy modelu.

# %% [markdown]
# ### Braki danych

# %%
print(f'{data[(data == "?").any(axis = 1)].shape[0]}')
# Out:
# 3620

# %%
data[data == "?"] = np.nan

# %%
data.isna().sum()
# Out:
# age                  0
# workclass         2799
# education            0
# education_num        0
# marital_status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     857
# income_level         0
# dtype: int64

# %%
data[data["workclass"].isna() & data["occupation"].isna()]
# Out:
#        age workclass     education  education_num         marital_status  \
# 27      54       NaN  Some-college             10     Married-civ-spouse
# 61      32       NaN       7th-8th              4  Married-spouse-absent
# 69      25       NaN  Some-college             10          Never-married
# 77      67       NaN          10th              6     Married-civ-spouse
# 106     17       NaN          10th              6          Never-married
# ...    ...       ...           ...            ...                    ...
# 48682   61       NaN  Some-college             10     Married-civ-spouse
# 48769   21       NaN  Some-college             10          Never-married
# 48800   73       NaN       HS-grad              9     Married-civ-spouse
# 48812   81       NaN     Assoc-voc             11     Married-civ-spouse
# 48838   64       NaN       HS-grad              9                Widowed
#
#       occupation    relationship                race     sex  capital_gain  \
# 27           NaN         Husband  Asian-Pac-Islander    Male           0.0
# 61           NaN   Not-in-family               White    Male           0.0
# 69           NaN       Own-child               White    Male           0.0
# 77           NaN         Husband               White    Male           0.0
# 106          NaN       Own-child               White  Female       34095.0
# ...          ...             ...                 ...     ...           ...
# 48682        NaN         Husband               White    Male           0.0
# 48769        NaN       Own-child               White  Female           0.0
# 48800        NaN         Husband               White    Male           0.0
# 48812        NaN         Husband               White    Male        2936.0
# 48838        NaN  Other-relative               Black    Male           0.0
#
#        capital_loss  hours_per_week native_country income_level
# 27              0.0            60.0          South         >50K
# 61              0.0            40.0            NaN        <=50K
# 69              0.0            40.0  United-States        <=50K
# 77              0.0             2.0  United-States        <=50K
# 106             0.0            32.0  United-States        <=50K
# ...             ...             ...            ...          ...
# 48682           0.0            14.0  United-States        <=50K
# 48769           0.0            30.0  United-States        <=50K
# 48800           0.0            25.0         Canada        <=50K
# 48812           0.0            20.0  United-States        <=50K
# 48838           0.0            40.0  United-States        <=50K
#
# [2799 rows x 14 columns]

# %% [markdown]
# Tam gdzie mamy brak w `workclass` mamy też brak w `occupation`, ale to wydaje sie naturalne.

# %% [markdown]
# #### Wypełnianie zmiennych z brakami
# W porzedniej wersji wiersze z brakami usuwaliśmy. Jednak po przeanalizowaniu problemu, postanowiliśmy braki danych wypełnić modami zmiennych.

# %%
print(data.mode().iloc[0])
data = data.fillna(data.mode().iloc[0])
data.head()
# Out:
# age                               36
# workclass                    Private
# education                    HS-grad
# education_num                      9
# marital_status    Married-civ-spouse
# occupation            Prof-specialty
# relationship                 Husband
# race                           White
# sex                             Male
# capital_gain                     0.0
# capital_loss                     0.0
# hours_per_week                  40.0
# native_country         United-States
# income_level                   <=50K
# Name: 0, dtype: object
#    age         workclass  education  education_num      marital_status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital_gain  \
# 0       Adm-clerical  Not-in-family  White    Male        2174.0
# 1    Exec-managerial        Husband  White    Male           0.0
# 2  Handlers-cleaners  Not-in-family  White    Male           0.0
# 3  Handlers-cleaners        Husband  Black    Male           0.0
# 4     Prof-specialty           Wife  Black  Female           0.0
#
#    capital_loss  hours_per_week native_country income_level
# 0           0.0            40.0  United-States        <=50K
# 1           0.0            13.0  United-States        <=50K
# 2           0.0            40.0  United-States        <=50K
# 3           0.0            40.0  United-States        <=50K
# 4           0.0            40.0           Cuba        <=50K

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income_level      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   education       48842 non-null  object
#  3   education_num   48842 non-null  int64
#  4   marital_status  48842 non-null  object
#  5   occupation      48842 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital_gain    48842 non-null  float64
#  10  capital_loss    48842 non-null  float64
#  11  hours_per_week  48842 non-null  float64
#  12  native_country  48842 non-null  object
#  13  income_level    48842 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# `education_num` określa poziom edukacji, natomiast `education` to wyrażony słownie poziom edukacji.

# %%
education_list = []
for i, name in data.groupby(["education_num", "education"]).groups.keys():
    education_list += [name]

data["education"] = pd.Categorical(data["education"], 
                                categories=education_list, ordered=True)
data
# Out:
#        age         workclass  education  education_num      marital_status  \
# 0       39         State-gov  Bachelors             13       Never-married
# 1       50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2       38           Private    HS-grad              9            Divorced
# 3       53           Private       11th              7  Married-civ-spouse
# 4       28           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48837   39           Private  Bachelors             13            Divorced
# 48838   64           Private    HS-grad              9             Widowed
# 48839   38           Private  Bachelors             13  Married-civ-spouse
# 48840   44           Private  Bachelors             13            Divorced
# 48841   35      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
#               occupation    relationship                race     sex  \
# 0           Adm-clerical   Not-in-family               White    Male
# 1        Exec-managerial         Husband               White    Male
# 2      Handlers-cleaners   Not-in-family               White    Male
# 3      Handlers-cleaners         Husband               Black    Male
# 4         Prof-specialty            Wife               Black  Female
# ...                  ...             ...                 ...     ...
# 48837     Prof-specialty   Not-in-family               White  Female
# 48838     Prof-specialty  Other-relative               Black    Male
# 48839     Prof-specialty         Husband               White    Male
# 48840       Adm-clerical       Own-child  Asian-Pac-Islander    Male
# 48841    Exec-managerial         Husband               White    Male
#
#        capital_gain  capital_loss  hours_per_week native_country income_level
# 0            2174.0           0.0            40.0  United-States        <=50K
# 1               0.0           0.0            13.0  United-States        <=50K
# 2               0.0           0.0            40.0  United-States        <=50K
# 3               0.0           0.0            40.0  United-States        <=50K
# 4               0.0           0.0            40.0           Cuba        <=50K
# ...             ...           ...             ...            ...          ...
# 48837           0.0           0.0            36.0  United-States        <=50K
# 48838           0.0           0.0            40.0  United-States        <=50K
# 48839           0.0           0.0            50.0  United-States        <=50K
# 48840        5455.0           0.0            40.0  United-States        <=50K
# 48841           0.0           0.0            60.0  United-States         >50K
#
# [48842 rows x 14 columns]

# %% [markdown]
# ## 3. Rozkłady zmiennych

# %% [markdown]
# ### Zmienne ilościowe

# %%
duration_dist = sns.histplot(data['age'],  binwidth = 1)
plt.show()

# %% [markdown]
# Rozkład przypomina w miarę normalny, z odcięciem przy 16 roku życia, wszystkim powyżej 90 roku życia przypisano wartość wieku 90.

# %% [markdown]
# Przy zmiennych `capital_gain` i `capital_loss` przeważa wartość 0 (która nie wnosi dużo informacji), więc zostanie pominięta.

# %%
data[["capital_gain", "capital_loss"]].hist(bins = 40, figsize = (10, 6))
plt.show()

# %% [markdown]
# Po pominięciu rekordów (0):

# %%
sns.displot(data = data[data["capital_gain"]>0], x = "capital_gain")
plt.show()

# %%
sns.displot(data = data[data["capital_loss"]>0], x = "capital_loss")
plt.show()

# %%
sns.displot(data = data, x = "hours_per_week", binwidth = 5)
plt.show()

# %% [markdown]
# ### Zmienne jakościowe

# %%
sns.countplot(y='workclass',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='workclass'>

# %%
sns.countplot(y='education',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='education'>

# %%
sns.countplot(y='marital_status',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='marital_status'>

# %%
sns.countplot(y='relationship',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='relationship'>

# %%
sns.countplot(y='race',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='race'>

# %%
sns.countplot(y='sex',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %% [markdown]
# ### Większość danych pochodzi ze Stanów Zjednoczonych

# %%
data['native_country'].value_counts().head(15)
# Out:
# native_country
# United-States         44689
# Mexico                  951
# Philippines             295
# Germany                 206
# Puerto-Rico             184
# Canada                  182
# El-Salvador             155
# India                   151
# Cuba                    138
# England                 127
# China                   122
# South                   115
# Jamaica                 106
# Italy                   105
# Dominican-Republic      103
# Name: count, dtype: int64

# %%
sns.countplot(y='native_country',data=data, color='gray')
# Out:
# <Axes: xlabel='count', ylabel='native_country'>

# %%
sns.countplot(y='native_country',data=data[data['native_country'] != 'United-States'], color='gray')
# Out:
# <Axes: xlabel='count', ylabel='native_country'>

# %% [markdown]
# ## 4. Kodowanie zmiennych kategorycznych

# %% [markdown]
# ### Zmienna `sex`
# Zamiana na wartości binarne: 1 - Male, 0 - Female

# %%
data['sex'] = (data['sex'] == 'Male')*1

# %% [markdown]
# ### Zmienna `income_level`
# Zamiana na wartości binarne: 1 - >50K, 0 - <=50K

# %%
data['income_level'] = (data['income_level'] == '>50K')*1

# %% [markdown]
# ### Zmienna `education`

# %% [markdown]
# Ponieważ każdy `education_num` odpowiada innej wsrtości `education`, to możemy usunąć drugą z nich.

# %%
data = data.drop(columns = "education")

# %% [markdown]
# ### Zmienna `race`

# %%
data.race.unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
data.groupby("race").count().sort_values("age", ascending = False)
# Out:
#                       age  workclass  education_num  marital_status  \
# race
# White               41762      41762          41762           41762
# Black                4685       4685           4685            4685
# Asian-Pac-Islander   1519       1519           1519            1519
# Amer-Indian-Eskimo    470        470            470             470
# Other                 406        406            406             406
#
#                     occupation  relationship    sex  capital_gain  \
# race
# White                    41762         41762  41762         41762
# Black                     4685          4685   4685          4685
# Asian-Pac-Islander        1519          1519   1519          1519
# Amer-Indian-Eskimo         470           470    470           470
# Other                      406           406    406           406
#
#                     capital_loss  hours_per_week  native_country  income_level
# race
# White                      41762           41762           41762         41762
# Black                       4685            4685            4685          4685
# Asian-Pac-Islander          1519            1519            1519          1519
# Amer-Indian-Eskimo           470             470             470           470
# Other                        406             406             406           406

# %% [markdown]
# Mamy prawie wyłącznie czarnoskórych i białoskórych ludzi.

# %% [markdown]
# W porzedniej wersji zakodowaliśmy rasę za pomocą poniższej funkcji, która osoby białoskóre za wartością 1, czarnoskóre 2, a pozostałe 3.

# %%
# def raceCategory(x):
#     if x == "White":
#         return 1
#     elif x == "Black":
#         return 2
#     else:
#         return 3

# %%
# data["race"] = data.apply(lambda x: raceCategory(x["race"]), axis = 1)

# %% [markdown]
# Jednak po przemyśleniu tego rozwiązania, postanowiliśmy kategoryzować zmienną `race` za pomocą one-hot.

# %% [markdown]
# Na początku zostawimy rasę "White" i "Black", a pozostałe rasy podliczamy do kategori "other".

# %%
data['race'] = np.where(
    (data['race']!="White") & (data['race']!="Black"),
    'other', data['race']
)

data
# Out:
#        age         workclass  education_num      marital_status  \
# 0       39         State-gov             13       Never-married
# 1       50  Self-emp-not-inc             13  Married-civ-spouse
# 2       38           Private              9            Divorced
# 3       53           Private              7  Married-civ-spouse
# 4       28           Private             13  Married-civ-spouse
# ...    ...               ...            ...                 ...
# 48837   39           Private             13            Divorced
# 48838   64           Private              9             Widowed
# 48839   38           Private             13  Married-civ-spouse
# 48840   44           Private             13            Divorced
# 48841   35      Self-emp-inc             13  Married-civ-spouse
#
#               occupation    relationship   race  sex  capital_gain  \
# 0           Adm-clerical   Not-in-family  White    1        2174.0
# 1        Exec-managerial         Husband  White    1           0.0
# 2      Handlers-cleaners   Not-in-family  White    1           0.0
# 3      Handlers-cleaners         Husband  Black    1           0.0
# 4         Prof-specialty            Wife  Black    0           0.0
# ...                  ...             ...    ...  ...           ...
# 48837     Prof-specialty   Not-in-family  White    0           0.0
# 48838     Prof-specialty  Other-relative  Black    1           0.0
# 48839     Prof-specialty         Husband  White    1           0.0
# 48840       Adm-clerical       Own-child  other    1        5455.0
# 48841    Exec-managerial         Husband  White    1           0.0
#
#        capital_loss  hours_per_week native_country  income_level
# 0               0.0            40.0  United-States             0
# 1               0.0            13.0  United-States             0
# 2               0.0            40.0  United-States             0
# 3               0.0            40.0  United-States             0
# 4               0.0            40.0           Cuba             0
# ...             ...             ...            ...           ...
# 48837           0.0            36.0  United-States             0
# 48838           0.0            40.0  United-States             0
# 48839           0.0            50.0  United-States             0
# 48840           0.0            40.0  United-States             0
# 48841           0.0            60.0  United-States             1
#
# [48842 rows x 13 columns]

# %% [markdown]
# Następnie dokonujemy one-hot encodingu:

# %%
encoded = pd.get_dummies(data["race"].astype(str), prefix='race')
data = data.drop("race", axis=1)
data = pd.concat([data, encoded], axis = 1)
data
# Out:
#        age         workclass  education_num      marital_status  \
# 0       39         State-gov             13       Never-married
# 1       50  Self-emp-not-inc             13  Married-civ-spouse
# 2       38           Private              9            Divorced
# 3       53           Private              7  Married-civ-spouse
# 4       28           Private             13  Married-civ-spouse
# ...    ...               ...            ...                 ...
# 48837   39           Private             13            Divorced
# 48838   64           Private              9             Widowed
# 48839   38           Private             13  Married-civ-spouse
# 48840   44           Private             13            Divorced
# 48841   35      Self-emp-inc             13  Married-civ-spouse
#
#               occupation    relationship  sex  capital_gain  capital_loss  \
# 0           Adm-clerical   Not-in-family    1        2174.0           0.0
# 1        Exec-managerial         Husband    1           0.0           0.0
# 2      Handlers-cleaners   Not-in-family    1           0.0           0.0
# 3      Handlers-cleaners         Husband    1           0.0           0.0
# 4         Prof-specialty            Wife    0           0.0           0.0
# ...                  ...             ...  ...           ...           ...
# 48837     Prof-specialty   Not-in-family    0           0.0           0.0
# 48838     Prof-specialty  Other-relative    1           0.0           0.0
# 48839     Prof-specialty         Husband    1           0.0           0.0
# 48840       Adm-clerical       Own-child    1        5455.0           0.0
# 48841    Exec-managerial         Husband    1           0.0           0.0
#
#        hours_per_week native_country  income_level  race_Black  race_White  \
# 0                40.0  United-States             0       False        True
# 1                13.0  United-States             0       False        True
# 2                40.0  United-States             0       False        True
# 3                40.0  United-States             0        True       False
# 4                40.0           Cuba             0        True       False
# ...               ...            ...           ...         ...         ...
# 48837            36.0  United-States             0       False        True
# 48838            40.0  United-States             0        True       False
# 48839            50.0  United-States             0       False        True
# 48840            40.0  United-States             0       False       False
# 48841            60.0  United-States             1       False        True
#
#        race_other
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 48837       False
# 48838       False
# 48839       False
# 48840        True
# 48841       False
#
# [48842 rows x 15 columns]

# %% [markdown]
# ### Zmienna `workclass`
# Przeprowadzmy one-hot encoding zmiennej `workclass`.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

values = np.array(data["workclass"])

# integer encode
le = LabelEncoder()
integer_encoded = le.fit_transform(values)
data["workclass"] = integer_encoded
# Warto zauważyć, że to ma sens, tylko dla zmiennych, które reprezentują jakieś poziomy/kolejność (hierarchię)

# %% [markdown]
# ### Zmienna `occupation`
# Ta zmienna jest powiązana z `workclass` i wnosi podobne informcje, zatem usuniemy ją.

# %%
data = data.drop(columns = "occupation")

# %% [markdown]
# ### Zmienna `marital_status` i `relationship`

# %%
data.marital_status.unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Divorced',
#        'Married-spouse-absent', 'Separated', 'Married-AF-spouse',
#        'Widowed'], dtype=object)

# %%
data.relationship.unique()
# Out:
# array(['Not-in-family', 'Husband', 'Wife', 'Own-child', 'Unmarried',
#        'Other-relative'], dtype=object)

# %% [markdown]
# Obie zmienne wnoszą podobne informacje, ale w `relationship` mamy mniej różnych wartości (co ułatwia encoding), dlatego `marital_status` zostanie usunięte, a na `relationship` dokonamy encodingu.

# %%
data = data.drop(columns = "marital_status")

# %%
encoded = pd.get_dummies(data["relationship"].astype(str), prefix='relationship')
data = data.drop("relationship", axis=1)
data = pd.concat([data, encoded], axis = 1)
data
# Out:
#        age  workclass  education_num  sex  capital_gain  capital_loss  \
# 0       39          6             13    1        2174.0           0.0
# 1       50          5             13    1           0.0           0.0
# 2       38          3              9    1           0.0           0.0
# 3       53          3              7    1           0.0           0.0
# 4       28          3             13    0           0.0           0.0
# ...    ...        ...            ...  ...           ...           ...
# 48837   39          3             13    0           0.0           0.0
# 48838   64          3              9    1           0.0           0.0
# 48839   38          3             13    1           0.0           0.0
# 48840   44          3             13    1        5455.0           0.0
# 48841   35          4             13    1           0.0           0.0
#
#        hours_per_week native_country  income_level  race_Black  race_White  \
# 0                40.0  United-States             0       False        True
# 1                13.0  United-States             0       False        True
# 2                40.0  United-States             0       False        True
# 3                40.0  United-States             0        True       False
# 4                40.0           Cuba             0        True       False
# ...               ...            ...           ...         ...         ...
# 48837            36.0  United-States             0       False        True
# 48838            40.0  United-States             0        True       False
# 48839            50.0  United-States             0       False        True
# 48840            40.0  United-States             0       False       False
# 48841            60.0  United-States             1       False        True
#
#        race_other  relationship_Husband  relationship_Not-in-family  \
# 0           False                 False                        True
# 1           False                  True                       False
# 2           False                 False                        True
# 3           False                  True                       False
# 4           False                 False                       False
# ...           ...                   ...                         ...
# 48837       False                 False                        True
# 48838       False                 False                       False
# 48839       False                  True                       False
# 48840        True                 False                       False
# 48841       False                  True                       False
#
#        relationship_Other-relative  relationship_Own-child  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 48837                        False                   False
# 48838                         True                   False
# 48839                        False                   False
# 48840                        False                    True
# 48841                        False                   False
#
#        relationship_Unmarried  relationship_Wife
# 0                       False              False
# 1                       False              False
# 2                       False              False
# 3                       False              False
# 4                       False               True
# ...                       ...                ...
# 48837                   False              False
# 48838                   False              False
# 48839                   False              False
# 48840                   False              False
# 48841                   False              False
#
# [48842 rows x 18 columns]

# %% [markdown]
# ### Zmienna `native_country`
# Przeprowadzmy one-hot encoding zmiennej.

# %%
print(len(data.native_country.unique()))
data.native_country.unique()
# Out:
# 41
# array(['United-States', 'Cuba', 'Jamaica', 'India', 'Mexico', 'South',
#        'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany', 'Iran',
#        'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
data[["native_country", "age"]].groupby("native_country").count().sort_values("age", ascending = False)
# Out:
#                               age
# native_country
# United-States               44689
# Mexico                        951
# Philippines                   295
# Germany                       206
# Puerto-Rico                   184
# Canada                        182
# El-Salvador                   155
# India                         151
# Cuba                          138
# England                       127
# China                         122
# South                         115
# Jamaica                       106
# Italy                         105
# Dominican-Republic            103
# Japan                          92
# Guatemala                      88
# Poland                         87
# Vietnam                        86
# Columbia                       85
# Haiti                          75
# Portugal                       67
# Taiwan                         65
# Iran                           59
# Greece                         49
# Nicaragua                      49
# Peru                           46
# Ecuador                        45
# France                         38
# Ireland                        37
# Thailand                       30
# Hong                           30
# Cambodia                       28
# Trinadad&Tobago                27
# Outlying-US(Guam-USVI-etc)     23
# Laos                           23
# Yugoslavia                     23
# Scotland                       21
# Honduras                       20
# Hungary                        19
# Holand-Netherlands              1

# %%
data['native_country'] = np.where(
    (data['native_country']!="United-States") & (data['native_country']!="Mexico"),
    'other', data['native_country']
)

data
# Out:
#        age  workclass  education_num  sex  capital_gain  capital_loss  \
# 0       39          6             13    1        2174.0           0.0
# 1       50          5             13    1           0.0           0.0
# 2       38          3              9    1           0.0           0.0
# 3       53          3              7    1           0.0           0.0
# 4       28          3             13    0           0.0           0.0
# ...    ...        ...            ...  ...           ...           ...
# 48837   39          3             13    0           0.0           0.0
# 48838   64          3              9    1           0.0           0.0
# 48839   38          3             13    1           0.0           0.0
# 48840   44          3             13    1        5455.0           0.0
# 48841   35          4             13    1           0.0           0.0
#
#        hours_per_week native_country  income_level  race_Black  race_White  \
# 0                40.0  United-States             0       False        True
# 1                13.0  United-States             0       False        True
# 2                40.0  United-States             0       False        True
# 3                40.0  United-States             0        True       False
# 4                40.0          other             0        True       False
# ...               ...            ...           ...         ...         ...
# 48837            36.0  United-States             0       False        True
# 48838            40.0  United-States             0        True       False
# 48839            50.0  United-States             0       False        True
# 48840            40.0  United-States             0       False       False
# 48841            60.0  United-States             1       False        True
#
#        race_other  relationship_Husband  relationship_Not-in-family  \
# 0           False                 False                        True
# 1           False                  True                       False
# 2           False                 False                        True
# 3           False                  True                       False
# 4           False                 False                       False
# ...           ...                   ...                         ...
# 48837       False                 False                        True
# 48838       False                 False                       False
# 48839       False                  True                       False
# 48840        True                 False                       False
# 48841       False                  True                       False
#
#        relationship_Other-relative  relationship_Own-child  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 48837                        False                   False
# 48838                         True                   False
# 48839                        False                   False
# 48840                        False                    True
# 48841                        False                   False
#
#        relationship_Unmarried  relationship_Wife
# 0                       False              False
# 1                       False              False
# 2                       False              False
# 3                       False              False
# 4                       False               True
# ...                       ...                ...
# 48837                   False              False
# 48838                   False              False
# 48839                   False              False
# 48840                   False              False
# 48841                   False              False
#
# [48842 rows x 18 columns]

# %%
data[["native_country", "age"]].groupby("native_country").count().sort_values("age", ascending = False)
# Out:
#                   age
# native_country
# United-States   44689
# other            3202
# Mexico            951

# %%
encoded = pd.get_dummies(data["native_country"].astype(str), prefix='native_country')
data = data.drop("native_country", axis=1)
data = pd.concat([data, encoded], axis = 1)
data
# Out:
#        age  workclass  education_num  sex  capital_gain  capital_loss  \
# 0       39          6             13    1        2174.0           0.0
# 1       50          5             13    1           0.0           0.0
# 2       38          3              9    1           0.0           0.0
# 3       53          3              7    1           0.0           0.0
# 4       28          3             13    0           0.0           0.0
# ...    ...        ...            ...  ...           ...           ...
# 48837   39          3             13    0           0.0           0.0
# 48838   64          3              9    1           0.0           0.0
# 48839   38          3             13    1           0.0           0.0
# 48840   44          3             13    1        5455.0           0.0
# 48841   35          4             13    1           0.0           0.0
#
#        hours_per_week  income_level  race_Black  race_White  race_other  \
# 0                40.0             0       False        True       False
# 1                13.0             0       False        True       False
# 2                40.0             0       False        True       False
# 3                40.0             0        True       False       False
# 4                40.0             0        True       False       False
# ...               ...           ...         ...         ...         ...
# 48837            36.0             0       False        True       False
# 48838            40.0             0        True       False       False
# 48839            50.0             0       False        True       False
# 48840            40.0             0       False       False        True
# 48841            60.0             1       False        True       False
#
#        relationship_Husband  relationship_Not-in-family  \
# 0                     False                        True
# 1                      True                       False
# 2                     False                        True
# 3                      True                       False
# 4                     False                       False
# ...                     ...                         ...
# 48837                 False                        True
# 48838                 False                       False
# 48839                  True                       False
# 48840                 False                       False
# 48841                  True                       False
#
#        relationship_Other-relative  relationship_Own-child  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 48837                        False                   False
# 48838                         True                   False
# 48839                        False                   False
# 48840                        False                    True
# 48841                        False                   False
#
#        relationship_Unmarried  relationship_Wife  native_country_Mexico  \
# 0                       False              False                  False
# 1                       False              False                  False
# 2                       False              False                  False
# 3                       False              False                  False
# 4                       False               True                  False
# ...                       ...                ...                    ...
# 48837                   False              False                  False
# 48838                   False              False                  False
# 48839                   False              False                  False
# 48840                   False              False                  False
# 48841                   False              False                  False
#
#        native_country_United-States  native_country_other
# 0                              True                 False
# 1                              True                 False
# 2                              True                 False
# 3                              True                 False
# 4                             False                  True
# ...                             ...                   ...
# 48837                          True                 False
# 48838                          True                 False
# 48839                          True                 False
# 48840                          True                 False
# 48841                          True                 False
#
# [48842 rows x 20 columns]

# %% [markdown]
# W poprzedniej wersji dokonaliśmy Ordinal Encoding bez usuwania mniej licznych narodowości, za pomocą poniższego kodu:

# %%
# # data.groupby(['native_country']).size().sort_values(ascending=False)

# values = np.array(data["native_country"])

# integer_encoded = le.fit_transform(values)
# data["native_country"] = integer_encoded

# data

# %%
data = pd.concat([data['income_level'], data.drop('income_level', axis=1)], axis = 1)
data
# Out:
#        income_level  age  workclass  education_num  sex  capital_gain  \
# 0                 0   39          6             13    1        2174.0
# 1                 0   50          5             13    1           0.0
# 2                 0   38          3              9    1           0.0
# 3                 0   53          3              7    1           0.0
# 4                 0   28          3             13    0           0.0
# ...             ...  ...        ...            ...  ...           ...
# 48837             0   39          3             13    0           0.0
# 48838             0   64          3              9    1           0.0
# 48839             0   38          3             13    1           0.0
# 48840             0   44          3             13    1        5455.0
# 48841             1   35          4             13    1           0.0
#
#        capital_loss  hours_per_week  race_Black  race_White  race_other  \
# 0               0.0            40.0       False        True       False
# 1               0.0            13.0       False        True       False
# 2               0.0            40.0       False        True       False
# 3               0.0            40.0        True       False       False
# 4               0.0            40.0        True       False       False
# ...             ...             ...         ...         ...         ...
# 48837           0.0            36.0       False        True       False
# 48838           0.0            40.0        True       False       False
# 48839           0.0            50.0       False        True       False
# 48840           0.0            40.0       False       False        True
# 48841           0.0            60.0       False        True       False
#
#        relationship_Husband  relationship_Not-in-family  \
# 0                     False                        True
# 1                      True                       False
# 2                     False                        True
# 3                      True                       False
# 4                     False                       False
# ...                     ...                         ...
# 48837                 False                        True
# 48838                 False                       False
# 48839                  True                       False
# 48840                 False                       False
# 48841                  True                       False
#
#        relationship_Other-relative  relationship_Own-child  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 48837                        False                   False
# 48838                         True                   False
# 48839                        False                   False
# 48840                        False                    True
# 48841                        False                   False
#
#        relationship_Unmarried  relationship_Wife  native_country_Mexico  \
# 0                       False              False                  False
# 1                       False              False                  False
# 2                       False              False                  False
# 3                       False              False                  False
# 4                       False               True                  False
# ...                       ...                ...                    ...
# 48837                   False              False                  False
# 48838                   False              False                  False
# 48839                   False              False                  False
# 48840                   False              False                  False
# 48841                   False              False                  False
#
#        native_country_United-States  native_country_other
# 0                              True                 False
# 1                              True                 False
# 2                              True                 False
# 3                              True                 False
# 4                             False                  True
# ...                             ...                   ...
# 48837                          True                 False
# 48838                          True                 False
# 48839                          True                 False
# 48840                          True                 False
# 48841                          True                 False
#
# [48842 rows x 20 columns]

# %% [markdown]
# ## 5. Korelacje

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(method = "pearson"), annot=False, vmin=-1, vmax=1, cmap="BrBG")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(method = "spearman"), annot=False, vmin=-1, vmax=1, cmap="BrBG")
plt.show()

# %% [markdown]
# Wygląda na to, że nie mamy silnych korelacji. Najbardziej skorelowane z naszą zmienną do predykcji `income_level` są: `age`, `education_num`, `sex`, `hours_per_week`, `Husband`.

# %%
plt.figure(figsize = (7, 5))
ax = sns.countplot(data = data, x = "income_level", label="count")
for p in ax.patches:
        ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+250))
plt.title("Number of people in income level groups", fontsize=14)
plt.xlabel("Income level", fontsize=14)
plt.ylabel("Number of people", fontsize=14)
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.violinplot(data=data, x="income_level", y="hours_per_week", scale = "count")
plt.title("Income level groups vs weekly working hours", fontsize=14)
plt.xlabel("Income level", fontsize=14)
plt.ylabel("Weekly working hours", fontsize=14)
plt.show()
# Out:
# C:\Users\mipec\AppData\Local\Temp\ipykernel_4828\659434259.py:2: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=data, x="income_level", y="hours_per_week", scale = "count")

# %% [markdown]
# Duża część z tych, którzy zarabiają więcej niż 50k to ludzie pracujacy więcej niż 40h/week.

# %%
plt.figure(figsize = (10, 8))
sns.violinplot(data=data, x="income_level", y="age", scale = "count")
plt.title("Income level groups vs age", fontsize=14)
plt.xlabel("Income level", fontsize=14)
plt.ylabel("age", fontsize=14)
plt.show()
# Out:
# C:\Users\mipec\AppData\Local\Temp\ipykernel_4828\1429918329.py:2: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=data, x="income_level", y="age", scale = "count")

# %% [markdown]
# Widzimy, że rozkład wieku ludzi poniżej naszego progu 50k przypomina piramidę demograficzną, natomiast wykres po prawej - już nie.
# Przypomina on bardziej rozkład normalny, ze średnią około 45 roku życia.

# %%
data.groupby('education_num')["income_level"].value_counts(normalize=True).unstack('income_level').plot.bar(stacked=True, figsize = (16, 8))
plt.title("Income level groups vs education_level", fontsize=14)
plt.xticks(rotation = 45)
plt.xlabel("Education level", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Widzimy jak silnie poziom edukacji jest związany z prawdopodobieństwem znalezienia się w grupie >50k.

# %%
workclasses_plot_data = (
    data.groupby('workclass')["income_level"]
    .value_counts(normalize=True)
    .unstack('income_level')
)

workclasses_plot_data = workclasses_plot_data.sort_values(by=0, ascending=False)

workclasses_plot_data.plot.bar(stacked=True, figsize=(12, 8))
plt.xticks(rotation=0)
plt.title("Income level groups vs encoded work class", fontsize=14)
plt.xlabel("Work class", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Największy % ludzi powyżej progu zarobkowego znajduje się w kategorii `samozatrudnienie`.

# %% [markdown]
# ## 6. Importowanie tabelki z danymi do CSV
# Aby ułatwić pracę w kolejnych etapach, dane po pre-processingu zapiszemy do pliku w formacie CSV.

# %%
data
# Out:
#        income_level  age  workclass  education_num  sex  capital_gain  \
# 0                 0   39          6             13    1        2174.0
# 1                 0   50          5             13    1           0.0
# 2                 0   38          3              9    1           0.0
# 3                 0   53          3              7    1           0.0
# 4                 0   28          3             13    0           0.0
# ...             ...  ...        ...            ...  ...           ...
# 48837             0   39          3             13    0           0.0
# 48838             0   64          3              9    1           0.0
# 48839             0   38          3             13    1           0.0
# 48840             0   44          3             13    1        5455.0
# 48841             1   35          4             13    1           0.0
#
#        capital_loss  hours_per_week  race_Black  race_White  race_other  \
# 0               0.0            40.0       False        True       False
# 1               0.0            13.0       False        True       False
# 2               0.0            40.0       False        True       False
# 3               0.0            40.0        True       False       False
# 4               0.0            40.0        True       False       False
# ...             ...             ...         ...         ...         ...
# 48837           0.0            36.0       False        True       False
# 48838           0.0            40.0        True       False       False
# 48839           0.0            50.0       False        True       False
# 48840           0.0            40.0       False       False        True
# 48841           0.0            60.0       False        True       False
#
#        relationship_Husband  relationship_Not-in-family  \
# 0                     False                        True
# 1                      True                       False
# 2                     False                        True
# 3                      True                       False
# 4                     False                       False
# ...                     ...                         ...
# 48837                 False                        True
# 48838                 False                       False
# 48839                  True                       False
# 48840                 False                       False
# 48841                  True                       False
#
#        relationship_Other-relative  relationship_Own-child  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 48837                        False                   False
# 48838                         True                   False
# 48839                        False                   False
# 48840                        False                    True
# 48841                        False                   False
#
#        relationship_Unmarried  relationship_Wife  native_country_Mexico  \
# 0                       False              False                  False
# 1                       False              False                  False
# 2                       False              False                  False
# 3                       False              False                  False
# 4                       False               True                  False
# ...                       ...                ...                    ...
# 48837                   False              False                  False
# 48838                   False              False                  False
# 48839                   False              False                  False
# 48840                   False              False                  False
# 48841                   False              False                  False
#
#        native_country_United-States  native_country_other
# 0                              True                 False
# 1                              True                 False
# 2                              True                 False
# 3                              True                 False
# 4                             False                  True
# ...                             ...                   ...
# 48837                          True                 False
# 48838                          True                 False
# 48839                          True                 False
# 48840                          True                 False
# 48841                          True                 False
#
# [48842 rows x 20 columns]

# %%
data.to_csv('census_income_dataset_processed.csv')
